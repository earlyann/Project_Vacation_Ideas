# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import pprint

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 621

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f'api.openweathermap.org/data/2.5/forecast/daily?q={city}&appid={weather_api_key}&units=metric'

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url= f'https://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}&units=metric'
    city_responses = requests.get(city_url).json()

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = city_responses['weather']

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_responses['coord']['lat']
        city_lng = city_responses['coord']['lon']
        city_max_temp = city_responses['main']['temp_max']
        city_humidity = city_responses['main']['humidity']
        city_clouds = city_responses['clouds']['all']
        city_wind = city_responses['wind']['speed']
        city_country = city_responses['sys']['country']
        city_date = city_responses['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | mehamn
# Processing Record 3 of Set 1 | massakory
# Processing Record 4 of Set 1 | northam
# Processing Record 5 of Set 1 | port hedland
# Processing Record 6 of Set 1 | clyde river
# Processing Record 7 of Set 1 | beringovskiy
# Processing Record 8 of Set 1 | klaksvik
# Processing Record 9 of Set 1 | dikson
# Processing Record 10 of Set 1 | abeokuta
# Processing Record 11 of Set 1 | tura
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | tete
# Processing Record 14 of Set 1 | hermanus
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | avera
# Processing Record 17 of Set 1 | atuona
# Processing Record 18 of Set 1 | hobart
# Processing Record 19 of Set 1 | kapaa
# Processing Record 20 of Set 1 | mataura
# Processing Record 21 of Set 1 | anisoc
# Processing Record 22 of Set 1 | vaini
# Processing Record 23 of Set 1 | lavrentiya
# Processing Record 24 of Set 1 | saint george
# Processing Record 25 of Set 1 | weligama
# Processing Record 26 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 1 | sioux lookout
# Processing Record 28 of Set 1 | barawe
# City not found. Skipping...
# Processing Record 29 of Set 1 | saskylakh
# Processing Record 30 of Set 1 | nakusp
# Processing Record 31 of Set 1 | jamestown
# Processing Record 32 of Set 1 | lincoln
# Processing Record 33 of Set 1 | bethel
# Processing Record 34 of Set 1 | port elizabeth
# Processing Record 35 of Set 1 | barrow
# Processing Record 36 of Set 1 | villarrica
# Processing Record 37 of Set 1 | victoria
# Processing Record 38 of Set 1 | cape town
# Processing Record 39 of Set 1 | punta arenas
# Processing Record 40 of Set 1 | bubaque
# Processing Record 41 of Set 1 | gazanjyk
# Processing Record 42 of Set 1 | east london
# Processing Record 43 of Set 1 | nandu
# Processing Record 44 of Set 1 | qaanaaq
# Processing Record 45 of Set 1 | radcliff
# Processing Record 46 of Set 1 | sambava
# Processing Record 47 of Set 1 | jibuti
# Processing Record 48 of Set 1 | bluff
# Processing Record 49 of Set 1 | cockburn harbour
# City not found. Skipping...
# Processing Record 50 of Set 1 | newtownards
# Processing Record 0 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 1 of Set 2 | salisbury
# Processing Record 2 of Set 2 | grand gaube
# Processing Record 3 of Set 2 | kumluca
# Processing Record 4 of Set 2 | saint anthony
# Processing Record 5 of Set 2 | chuy
# Processing Record 6 of Set 2 | butaritari
# Processing Record 7 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 8 of Set 2 | saint-francois
# Processing Record 9 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 2 | kavieng
# Processing Record 11 of Set 2 | bredasdorp
# Processing Record 12 of Set 2 | cherskiy
# Processing Record 13 of Set 2 | cherepanovo
# Processing Record 14 of Set 2 | conceicao do araguaia
# Processing Record 15 of Set 2 | ribeira grande
# Processing Record 16 of Set 2 | alyangula
# Processing Record 17 of Set 2 | new norfolk
# Processing Record 18 of Set 2 | rikitea
# Processing Record 19 of Set 2 | carnarvon
# Processing Record 20 of Set 2 | port alfred
# Processing Record 21 of Set 2 | black diamond
# Processing Record 22 of Set 2 | caravelas
# Processing Record 23 of Set 2 | tual
# Processing Record 24 of Set 2 | stoyba
# City not found. Skipping...
# Processing Record 25 of Set 2 | vanavara
# Processing Record 26 of Set 2 | chapais
# Processing Record 27 of Set 2 | asfi
# Processing Record 28 of Set 2 | mangrol
# Processing Record 29 of Set 2 | fort wellington
# Processing Record 30 of Set 2 | tabou
# Processing Record 31 of Set 2 | salalah
# Processing Record 32 of Set 2 | kodiak
# Processing Record 33 of Set 2 | aklavik
# Processing Record 34 of Set 2 | hamilton
# Processing Record 35 of Set 2 | jutai
# Processing Record 36 of Set 2 | batemans bay
# Processing Record 37 of Set 2 | iqaluit
# Processing Record 38 of Set 2 | kamaishi
# Processing Record 39 of Set 2 | saint-joseph
# Processing Record 40 of Set 2 | kamakwie
# Processing Record 41 of Set 2 | biltine
# Processing Record 42 of Set 2 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 43 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 44 of Set 2 | kungurtug
# Processing Record 45 of Set 2 | grindavik
# Processing Record 46 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 2 | mar del plata
# Processing Record 48 of Set 2 | bluffton
# Processing Record 49 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 0 of Set 3 | utiroa
# City not found. Skipping...
# Processing Record 1 of Set 3 | ambovombe
# Processing Record 2 of Set 3 | puerto ayora
# Processing Record 3 of Set 3 | padang
# Processing Record 4 of Set 3 | kikwit
# Processing Record 5 of Set 3 | tuktoyaktuk
# Processing Record 6 of Set 3 | guerrero negro
# Processing Record 7 of Set 3 | sao lourenco da serra
# Processing Record 8 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 9 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 10 of Set 3 | port hardy
# Processing Record 11 of Set 3 | dubbo
# Processing Record 12 of Set 3 | dingle
# Processing Record 13 of Set 3 | tuatapere
# Processing Record 14 of Set 3 | castro
# Processing Record 15 of Set 3 | provideniya
# Processing Record 16 of Set 3 | labutta
# City not found. Skipping...
# Processing Record 17 of Set 3 | lakes entrance
# Processing Record 18 of Set 3 | whitehorse
# Processing Record 19 of Set 3 | saldanha
# Processing Record 20 of Set 3 | hilo
# Processing Record 21 of Set 3 | saint-philippe
# Processing Record 22 of Set 3 | elizabeth city
# Processing Record 23 of Set 3 | alofi
# Processing Record 24 of Set 3 | ancud
# Processing Record 25 of Set 3 | hithadhoo
# Processing Record 26 of Set 3 | verkhoyansk
# Processing Record 27 of Set 3 | thompson
# Processing Record 28 of Set 3 | pangkalanbuun
# Processing Record 29 of Set 3 | dossor
# Processing Record 30 of Set 3 | pundaguitan
# Processing Record 31 of Set 3 | rincon
# Processing Record 32 of Set 3 | bengkulu
# Processing Record 33 of Set 3 | pangai
# Processing Record 34 of Set 3 | zhigansk
# Processing Record 35 of Set 3 | khatanga
# Processing Record 36 of Set 3 | barcelos
# Processing Record 37 of Set 3 | souillac
# Processing Record 38 of Set 3 | antalaha
# Processing Record 39 of Set 3 | kyshtovka
# Processing Record 40 of Set 3 | erenhot
# Processing Record 41 of Set 3 | andenes
# Processing Record 42 of Set 3 | palmer
# Processing Record 43 of Set 3 | pevek
# Processing Record 44 of Set 3 | san patricio
# Processing Record 45 of Set 3 | lebu
# Processing Record 46 of Set 3 | solnechnyy
# Processing Record 47 of Set 3 | bilopillya
# Processing Record 48 of Set 3 | lingao
# Processing Record 49 of Set 3 | guarda
# Processing Record 0 of Set 4 | birao
# Processing Record 1 of Set 4 | grand centre
# City not found. Skipping...
# Processing Record 2 of Set 4 | marovoay
# Processing Record 3 of Set 4 | coihaique
# Processing Record 4 of Set 4 | arman
# Processing Record 5 of Set 4 | tiruvottiyur
# City not found. Skipping...
# Processing Record 6 of Set 4 | sabinas
# Processing Record 7 of Set 4 | dhidhdhoo
# Processing Record 8 of Set 4 | haines junction
# Processing Record 9 of Set 4 | avarua
# Processing Record 10 of Set 4 | palembang
# Processing Record 11 of Set 4 | lompoc
# Processing Record 12 of Set 4 | milazzo
# Processing Record 13 of Set 4 | saint-georges
# Processing Record 14 of Set 4 | constitucion
# Processing Record 15 of Set 4 | severo-kurilsk
# Processing Record 16 of Set 4 | vila franca do campo
# Processing Record 17 of Set 4 | preobrazhenskaya
# City not found. Skipping...
# Processing Record 18 of Set 4 | tasiilaq
# Processing Record 19 of Set 4 | mana
# Processing Record 20 of Set 4 | kaitangata
# Processing Record 21 of Set 4 | tsuruga
# Processing Record 22 of Set 4 | zabaykalsk
# Processing Record 23 of Set 4 | ukiah
# Processing Record 24 of Set 4 | tiksi
# Processing Record 25 of Set 4 | vigrestad
# Processing Record 26 of Set 4 | lyantonde
# Processing Record 27 of Set 4 | maumere
# Processing Record 28 of Set 4 | araouane
# Processing Record 29 of Set 4 | abeche
# Processing Record 30 of Set 4 | tahoua
# Processing Record 31 of Set 4 | makakilo city
# Processing Record 32 of Set 4 | jabinyanah
# Processing Record 33 of Set 4 | kashan
# Processing Record 34 of Set 4 | kruisfontein
# Processing Record 35 of Set 4 | tobermory
# Processing Record 36 of Set 4 | impfondo
# Processing Record 37 of Set 4 | arraial do cabo
# Processing Record 38 of Set 4 | bata
# Processing Record 39 of Set 4 | ust-ishim
# Processing Record 40 of Set 4 | othonoi
# City not found. Skipping...
# Processing Record 41 of Set 4 | yellowknife
# Processing Record 42 of Set 4 | norman wells
# Processing Record 43 of Set 4 | khani
# Processing Record 44 of Set 4 | severnyy
# Processing Record 45 of Set 4 | roma
# Processing Record 46 of Set 4 | cayenne
# Processing Record 47 of Set 4 | tokur
# Processing Record 48 of Set 4 | isangel
# Processing Record 49 of Set 4 | muravlenko
# Processing Record 0 of Set 5 | gorontalo
# Processing Record 1 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 5 | faanui
# Processing Record 3 of Set 5 | belaya gora
# Processing Record 4 of Set 5 | sunam
# Processing Record 5 of Set 5 | yulara
# Processing Record 6 of Set 5 | beloha
# Processing Record 7 of Set 5 | san jose
# Processing Record 8 of Set 5 | nouadhibou
# Processing Record 9 of Set 5 | nikolayevsk-na-amure
# Processing Record 10 of Set 5 | lamu
# Processing Record 11 of Set 5 | raudeberg
# Processing Record 12 of Set 5 | guatire
# Processing Record 13 of Set 5 | los llanos de aridane
# Processing Record 14 of Set 5 | kysyl-syr
# Processing Record 15 of Set 5 | amuntai
# Processing Record 16 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 17 of Set 5 | cairns
# Processing Record 18 of Set 5 | wesselsbron
# Processing Record 19 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 20 of Set 5 | savalou
# Processing Record 21 of Set 5 | esperance
# Processing Record 22 of Set 5 | luderitz
# Processing Record 23 of Set 5 | boyolangu
# Processing Record 24 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 5 | havre-saint-pierre
# Processing Record 26 of Set 5 | lysva
# Processing Record 27 of Set 5 | sabha
# Processing Record 28 of Set 5 | tonantins
# Processing Record 29 of Set 5 | fare
# Processing Record 30 of Set 5 | nyurba
# Processing Record 31 of Set 5 | georgetown
# Processing Record 32 of Set 5 | puerto leguizamo
# Processing Record 33 of Set 5 | new castle
# Processing Record 34 of Set 5 | yenotayevka
# Processing Record 35 of Set 5 | gamboma
# Processing Record 36 of Set 5 | gurgentepe
# Processing Record 37 of Set 5 | puerto del rosario
# Processing Record 38 of Set 5 | nikolskoye
# Processing Record 39 of Set 5 | tanout
# Processing Record 40 of Set 5 | doume
# Processing Record 41 of Set 5 | contamana
# Processing Record 42 of Set 5 | fort nelson
# Processing Record 43 of Set 5 | vuktyl
# Processing Record 44 of Set 5 | craig
# Processing Record 45 of Set 5 | viedma
# Processing Record 46 of Set 5 | lewisporte
# Processing Record 47 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 48 of Set 5 | rawson
# Processing Record 49 of Set 5 | copala
# Processing Record 0 of Set 6 | raymondville
# Processing Record 1 of Set 6 | nhulunbuy
# Processing Record 2 of Set 6 | colares
# Processing Record 3 of Set 6 | paita
# Processing Record 4 of Set 6 | ariquemes
# Processing Record 5 of Set 6 | bara
# Processing Record 6 of Set 6 | dagana
# Processing Record 7 of Set 6 | geraldton
# Processing Record 8 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 6 | mareeba
# Processing Record 10 of Set 6 | cap malheureux
# Processing Record 11 of Set 6 | qingan
# City not found. Skipping...
# Processing Record 12 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 6 | sechura
# Processing Record 14 of Set 6 | masterton
# Processing Record 15 of Set 6 | sao filipe
# Processing Record 16 of Set 6 | cacador
# Processing Record 17 of Set 6 | touros
# Processing Record 18 of Set 6 | urengoy
# Processing Record 19 of Set 6 | bakonyszentlaszlo
# Processing Record 20 of Set 6 | abu samrah
# Processing Record 21 of Set 6 | vostok
# Processing Record 22 of Set 6 | bonthe
# Processing Record 23 of Set 6 | zhanakorgan
# Processing Record 24 of Set 6 | tiznit
# Processing Record 25 of Set 6 | ayagoz
# Processing Record 26 of Set 6 | pochutla
# Processing Record 27 of Set 6 | cacapava
# Processing Record 28 of Set 6 | santa lucia
# Processing Record 29 of Set 6 | margate
# Processing Record 30 of Set 6 | talnakh
# Processing Record 31 of Set 6 | antofagasta
# Processing Record 32 of Set 6 | khandyga
# Processing Record 33 of Set 6 | la ronge
# Processing Record 34 of Set 6 | ixtapa
# Processing Record 35 of Set 6 | port lincoln
# Processing Record 36 of Set 6 | prince george
# Processing Record 37 of Set 6 | baykalsk
# Processing Record 38 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 39 of Set 6 | acapulco
# Processing Record 40 of Set 6 | balikpapan
# Processing Record 41 of Set 6 | saint-augustin
# Processing Record 42 of Set 6 | azimur
# City not found. Skipping...
# Processing Record 43 of Set 6 | tigre
# Processing Record 44 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 6 | kununurra
# Processing Record 46 of Set 6 | chumikan
# Processing Record 47 of Set 6 | heide
# Processing Record 48 of Set 6 | ndele
# Processing Record 49 of Set 6 | quarteira
# Processing Record 0 of Set 7 | sterling heights
# Processing Record 1 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 2 of Set 7 | kwekwe
# Processing Record 3 of Set 7 | upernavik
# Processing Record 4 of Set 7 | udachnyy
# Processing Record 5 of Set 7 | lata
# Processing Record 6 of Set 7 | xichang
# Processing Record 7 of Set 7 | chokurdakh
# Processing Record 8 of Set 7 | christchurch
# Processing Record 9 of Set 7 | torbay
# Processing Record 10 of Set 7 | mahebourg
# Processing Record 11 of Set 7 | gornopravdinsk
# Processing Record 12 of Set 7 | naugarzan
# City not found. Skipping...
# Processing Record 13 of Set 7 | pishin
# Processing Record 14 of Set 7 | ryotsu
# Processing Record 15 of Set 7 | hobyo
# Processing Record 16 of Set 7 | ituporanga
# Processing Record 17 of Set 7 | honningsvag
# Processing Record 18 of Set 7 | longyearbyen
# Processing Record 19 of Set 7 | xining
# Processing Record 20 of Set 7 | svetlyy
# Processing Record 21 of Set 7 | grand-lahou
# Processing Record 22 of Set 7 | bahia blanca
# Processing Record 23 of Set 7 | mantua
# Processing Record 24 of Set 7 | davila
# Processing Record 25 of Set 7 | ritchie
# Processing Record 26 of Set 7 | havoysund
# Processing Record 27 of Set 7 | noumea
# Processing Record 28 of Set 7 | katsuura
# Processing Record 29 of Set 7 | marathon
# Processing Record 30 of Set 7 | airai
# Processing Record 31 of Set 7 | hasaki
# Processing Record 32 of Set 7 | ardistan
# City not found. Skipping...
# Processing Record 33 of Set 7 | baykit
# Processing Record 34 of Set 7 | mount hagen
# Processing Record 35 of Set 7 | namibe
# Processing Record 36 of Set 7 | traverse city
# Processing Record 37 of Set 7 | paucartambo
# City not found. Skipping...
# Processing Record 38 of Set 7 | la ligua
# Processing Record 39 of Set 7 | camacha
# Processing Record 40 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 41 of Set 7 | homer
# Processing Record 42 of Set 7 | port-gentil
# Processing Record 43 of Set 7 | bend
# Processing Record 44 of Set 7 | bulgan
# Processing Record 45 of Set 7 | daru
# Processing Record 46 of Set 7 | labuhan
# Processing Record 47 of Set 7 | mocambique
# City not found. Skipping...
# Processing Record 48 of Set 7 | gainesville
# Processing Record 49 of Set 7 | mount gambier
# Processing Record 0 of Set 8 | baherden
# Processing Record 1 of Set 8 | codrington
# Processing Record 2 of Set 8 | staroutkinsk
# Processing Record 3 of Set 8 | auki
# Processing Record 4 of Set 8 | marsa matruh
# Processing Record 5 of Set 8 | vila velha
# Processing Record 6 of Set 8 | poum
# Processing Record 7 of Set 8 | miles city
# Processing Record 8 of Set 8 | tomatlan
# Processing Record 9 of Set 8 | krasnoselkup
# Processing Record 10 of Set 8 | mananara
# Processing Record 11 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 12 of Set 8 | sandwick
# Processing Record 13 of Set 8 | dunedin
# Processing Record 14 of Set 8 | villa union
# Processing Record 15 of Set 8 | kahului
# Processing Record 16 of Set 8 | kavaratti
# Processing Record 17 of Set 8 | muscat
# Processing Record 18 of Set 8 | inirida
# Processing Record 19 of Set 8 | bar harbor
# Processing Record 20 of Set 8 | berlevag
# Processing Record 21 of Set 8 | hohhot
# Processing Record 22 of Set 8 | novyy urengoy
# Processing Record 23 of Set 8 | lima
# Processing Record 24 of Set 8 | sinnamary
# Processing Record 25 of Set 8 | nara
# Processing Record 26 of Set 8 | lazaro cardenas
# Processing Record 27 of Set 8 | verkhniy ufaley
# Processing Record 28 of Set 8 | savinka
# Processing Record 29 of Set 8 | sangar
# Processing Record 30 of Set 8 | ilulissat
# Processing Record 31 of Set 8 | waddan
# Processing Record 32 of Set 8 | eldikan
# City not found. Skipping...
# Processing Record 33 of Set 8 | uk
# City not found. Skipping...
# Processing Record 34 of Set 8 | kapustin yar-1
# City not found. Skipping...
# Processing Record 35 of Set 8 | adre
# Processing Record 36 of Set 8 | half moon bay
# Processing Record 37 of Set 8 | egvekinot
# Processing Record 38 of Set 8 | leningradskiy
# Processing Record 39 of Set 8 | dongfeng
# Processing Record 40 of Set 8 | ust-koksa
# Processing Record 41 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 42 of Set 8 | pisco
# Processing Record 43 of Set 8 | kem
# Processing Record 44 of Set 8 | cabo san lucas
# Processing Record 45 of Set 8 | sao jose da coroa grande
# Processing Record 46 of Set 8 | anadyr
# Processing Record 47 of Set 8 | sedalia
# Processing Record 48 of Set 8 | vestmanna
# Processing Record 49 of Set 8 | sychevka
# Processing Record 0 of Set 9 | juneau
# Processing Record 1 of Set 9 | olafsvik
# Processing Record 2 of Set 9 | huaiyin
# Processing Record 3 of Set 9 | fortuna
# Processing Record 4 of Set 9 | iskateley
# Processing Record 5 of Set 9 | merauke
# Processing Record 6 of Set 9 | oga
# Processing Record 7 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 8 of Set 9 | stodolishche
# Processing Record 9 of Set 9 | mount isa
# Processing Record 10 of Set 9 | karema
# Processing Record 11 of Set 9 | saryagash
# Processing Record 12 of Set 9 | saint-pierre
# Processing Record 13 of Set 9 | faya
# Processing Record 14 of Set 9 | qaqortoq
# Processing Record 15 of Set 9 | mogadishu
# Processing Record 16 of Set 9 | ahipara
# Processing Record 17 of Set 9 | nelson bay
# Processing Record 18 of Set 9 | benidorm
# Processing Record 19 of Set 9 | yeniseysk
# Processing Record 20 of Set 9 | piacabucu
# Processing Record 21 of Set 9 | estreito
# Processing Record 22 of Set 9 | nguruka
# Processing Record 23 of Set 9 | bambous virieux
# Processing Record 24 of Set 9 | walvis bay
# Processing Record 25 of Set 9 | maua
# Processing Record 26 of Set 9 | urumqi
# Processing Record 27 of Set 9 | strezhevoy
# Processing Record 28 of Set 9 | huarmey
# Processing Record 29 of Set 9 | dickinson
# Processing Record 30 of Set 9 | batsfjord
# Processing Record 31 of Set 9 | ingham
# Processing Record 32 of Set 9 | timizart
# Processing Record 33 of Set 9 | simao
# Processing Record 34 of Set 9 | monterrey
# Processing Record 35 of Set 9 | port blair
# Processing Record 36 of Set 9 | skibbereen
# Processing Record 37 of Set 9 | vardo
# Processing Record 38 of Set 9 | gimli
# Processing Record 39 of Set 9 | shu
# Processing Record 40 of Set 9 | vinh
# Processing Record 41 of Set 9 | elk point
# Processing Record 42 of Set 9 | bitkine
# Processing Record 43 of Set 9 | aquin
# Processing Record 44 of Set 9 | marsh harbour
# Processing Record 45 of Set 9 | vanimo
# Processing Record 46 of Set 9 | riyadh
# Processing Record 47 of Set 9 | tibiri
# Processing Record 48 of Set 9 | suez
# Processing Record 49 of Set 9 | amapa
# Processing Record 0 of Set 10 | khachrod
# Processing Record 1 of Set 10 | shenjiamen
# Processing Record 2 of Set 10 | koslan
# Processing Record 3 of Set 10 | macae
# Processing Record 4 of Set 10 | cabo rojo
# Processing Record 5 of Set 10 | watsa
# Processing Record 6 of Set 10 | flinders
# Processing Record 7 of Set 10 | careiro da varzea
# Processing Record 8 of Set 10 | orhei
# Processing Record 9 of Set 10 | santa cruz
# Processing Record 10 of Set 10 | biak
# Processing Record 11 of Set 10 | inderborskiy
# City not found. Skipping...
# Processing Record 12 of Set 10 | machacamarca
# Processing Record 13 of Set 10 | mogochin
# City not found. Skipping...
# Processing Record 14 of Set 10 | shenzhen
# Processing Record 15 of Set 10 | kidal
# Processing Record 16 of Set 10 | jaisalmer
# Processing Record 17 of Set 10 | muros
# Processing Record 18 of Set 10 | floro
# Processing Record 19 of Set 10 | copiapo
# Processing Record 20 of Set 10 | high rock
# Processing Record 21 of Set 10 | atbasar
# Processing Record 22 of Set 10 | gillette
# Processing Record 23 of Set 10 | miri
# Processing Record 24 of Set 10 | hervey bay
# Processing Record 25 of Set 10 | brae
# Processing Record 26 of Set 10 | khor
# Processing Record 27 of Set 10 | bereda
# Processing Record 28 of Set 10 | sungai siput utara
# City not found. Skipping...
# Processing Record 29 of Set 10 | lucapa
# Processing Record 30 of Set 10 | verkhnetulomskiy
# Processing Record 31 of Set 10 | teya
# Processing Record 32 of Set 10 | nizhniy kuranakh
# Processing Record 33 of Set 10 | poronaysk
# Processing Record 34 of Set 10 | tecpatan
# Processing Record 35 of Set 10 | ilheus
# Processing Record 36 of Set 10 | ostrovnoy
# Processing Record 37 of Set 10 | darlawn
# Processing Record 38 of Set 10 | baboua
# City not found. Skipping...
# Processing Record 39 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 40 of Set 10 | ostersund
# Processing Record 41 of Set 10 | phnum penh
# City not found. Skipping...
# Processing Record 42 of Set 10 | adrar
# Processing Record 43 of Set 10 | ondorhaan
# City not found. Skipping...
# Processing Record 44 of Set 10 | jieshi
# Processing Record 45 of Set 10 | banda aceh
# Processing Record 46 of Set 10 | podgorica
# Processing Record 47 of Set 10 | yarada
# Processing Record 48 of Set 10 | nanortalik
# Processing Record 49 of Set 10 | zaysan
# Processing Record 0 of Set 11 | loandjili
# Processing Record 1 of Set 11 | kapoeta
# Processing Record 2 of Set 11 | mandalgovi
# Processing Record 3 of Set 11 | pitimbu
# Processing Record 4 of Set 11 | alibag
# Processing Record 5 of Set 11 | yar-sale
# Processing Record 6 of Set 11 | nioro
# Processing Record 7 of Set 11 | rodrigues alves
# Processing Record 8 of Set 11 | broken hill
# Processing Record 9 of Set 11 | olden
# Processing Record 10 of Set 11 | boromlya
# Processing Record 11 of Set 11 | muskegon heights
# Processing Record 12 of Set 11 | gushikawa
# Processing Record 13 of Set 11 | peniche
# Processing Record 14 of Set 11 | thunder bay
# Processing Record 15 of Set 11 | college
# Processing Record 16 of Set 11 | mahon
# Processing Record 17 of Set 11 | san cristobal
# Processing Record 18 of Set 11 | sesimbra
# Processing Record 19 of Set 11 | acolla
# Processing Record 20 of Set 11 | shizuishan
# Processing Record 21 of Set 11 | cidreira
# Processing Record 22 of Set 11 | lalsot
# Processing Record 23 of Set 11 | kalga
# Processing Record 24 of Set 11 | bago
# Processing Record 25 of Set 11 | horodyshche
# Processing Record 26 of Set 11 | naze
# Processing Record 27 of Set 11 | borskoye
# Processing Record 28 of Set 11 | kinanah
# City not found. Skipping...
# Processing Record 29 of Set 11 | tuzha
# Processing Record 30 of Set 11 | chino valley
# Processing Record 31 of Set 11 | maneadero
# Processing Record 32 of Set 11 | sisimiut
# Processing Record 33 of Set 11 | ati
# Processing Record 34 of Set 11 | wakema
# Processing Record 35 of Set 11 | gasa
# Processing Record 36 of Set 11 | kalamnuri
# Processing Record 37 of Set 11 | green river
# Processing Record 38 of Set 11 | vila
# Processing Record 39 of Set 11 | hami
# Processing Record 40 of Set 11 | aporawan
# City not found. Skipping...
# Processing Record 41 of Set 11 | mergui
# City not found. Skipping...
# Processing Record 42 of Set 11 | terrace
# Processing Record 43 of Set 11 | tefe
# Processing Record 44 of Set 11 | portoferraio
# Processing Record 45 of Set 11 | yavaros
# Processing Record 46 of Set 11 | san policarpo
# Processing Record 47 of Set 11 | bhanpura
# Processing Record 48 of Set 11 | almaznyy
# Processing Record 49 of Set 11 | yermakovskoye
# Processing Record 0 of Set 12 | amboasary
# Processing Record 1 of Set 12 | katangli
# Processing Record 2 of Set 12 | umm kaddadah
# Processing Record 3 of Set 12 | nerchinskiy zavod
# Processing Record 4 of Set 12 | shaoxing
# Processing Record 5 of Set 12 | pokrovsk
# Processing Record 6 of Set 12 | pangnirtung
# Processing Record 7 of Set 12 | balkanabat
# Processing Record 8 of Set 12 | ketchikan
# Processing Record 9 of Set 12 | biloela
# Processing Record 10 of Set 12 | karamay
# City not found. Skipping...
# Processing Record 11 of Set 12 | sola
# Processing Record 12 of Set 12 | shanghai
# Processing Record 13 of Set 12 | acarau
# Processing Record 14 of Set 12 | santo tomas
# Processing Record 15 of Set 12 | van
# Processing Record 16 of Set 12 | sorochinsk
# Processing Record 17 of Set 12 | fryanovo
# Processing Record 18 of Set 12 | gat
# Processing Record 19 of Set 12 | embu
# Processing Record 20 of Set 12 | aranos
# Processing Record 21 of Set 12 | road town
# Processing Record 22 of Set 12 | ponta do sol
# Processing Record 23 of Set 12 | lewiston
# Processing Record 24 of Set 12 | inverell
# Processing Record 25 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 26 of Set 12 | puerto rico
# Processing Record 27 of Set 12 | ust-omchug
# Processing Record 28 of Set 12 | narsaq
# Processing Record 29 of Set 12 | umm lajj
# Processing Record 30 of Set 12 | maghama
# City not found. Skipping...
# Processing Record 31 of Set 12 | bela
# Processing Record 32 of Set 12 | atar
# Processing Record 33 of Set 12 | fairbanks
# Processing Record 34 of Set 12 | blagoyevo
# Processing Record 35 of Set 12 | lagoa
# Processing Record 36 of Set 12 | nargana
# Processing Record 37 of Set 12 | rantepao
# Processing Record 38 of Set 12 | opuwo
# Processing Record 39 of Set 12 | huamachuco
# Processing Record 40 of Set 12 | kjollefjord
# Processing Record 41 of Set 12 | west wendover
# Processing Record 42 of Set 12 | karratha
# Processing Record 43 of Set 12 | umm jarr
# City not found. Skipping...
# Processing Record 44 of Set 12 | butembo
# Processing Record 45 of Set 12 | nizhneyansk
# City not found. Skipping...
# Processing Record 46 of Set 12 | aykhal
# Processing Record 47 of Set 12 | gisborne
# Processing Record 48 of Set 12 | berdigestyakh
# Processing Record 49 of Set 12 | aitape
# Processing Record 0 of Set 13 | angra
# City not found. Skipping...
# Processing Record 1 of Set 13 | wuda
# Processing Record 2 of Set 13 | daura
# Processing Record 3 of Set 13 | ardakan
# Processing Record 4 of Set 13 | manokwari
# Processing Record 5 of Set 13 | pierre
# Processing Record 6 of Set 13 | itarema
# Processing Record 7 of Set 13 | namwala
# Processing Record 8 of Set 13 | lorengau
# Processing Record 9 of Set 13 | belen
# Processing Record 10 of Set 13 | ouesso
# Processing Record 11 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 12 of Set 13 | ponta delgada
# Processing Record 13 of Set 13 | ankang
# Processing Record 14 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 15 of Set 13 | jubayl
# City not found. Skipping...
# Processing Record 16 of Set 13 | iquique
# Processing Record 17 of Set 13 | menongue
# Processing Record 18 of Set 13 | parkes
# Processing Record 19 of Set 13 | shingu
# Processing Record 20 of Set 13 | hangu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          560
# Lat           560
# Lng           560
# Max Temp      560
# Humidity      560
# Cloudiness    560
# Wind Speed    560
# Country       560
# Date          560
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     busselton -33.6500  115.3333     16.50        92           0
# 1        mehamn  71.0357   27.8492      2.97        65          40
# 2     massakory  12.9960   15.7293     29.26        12          99
# 3       northam  51.0333   -4.2167      6.81        70          10
# 4  port hedland -20.3167  118.5667     28.03        83           5
#
#    Wind Speed Country        Date
# 0        5.19      AU  1675789328
# 1       19.03      NO  1675789601
# 2        4.86      TD  1675789602
# 3        1.51      GB  1675789602
# 4        1.54      AU  1675789603

# %%
# Export the City_Data into a csv
city_data_df.to_csv("/Users/laceymorgan/Desktop/Python_API_Challenge/output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("/Users/laceymorgan/Desktop/Python_API_Challenge/output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           busselton -33.6500  115.3333     16.50        92           0
# 1              mehamn  71.0357   27.8492      2.97        65          40
# 2           massakory  12.9960   15.7293     29.26        12          99
# 3             northam  51.0333   -4.2167      6.81        70          10
# 4        port hedland -20.3167  118.5667     28.03        83           5
#
#          Wind Speed Country        Date
# City_ID
# 0              5.19      AU  1675789328
# 1             19.03      NO  1675789601
# 2              4.86      TD  1675789602
# 3              1.51      GB  1675789602
# 4              1.54      AU  1675789603

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'],city_data_df['Max Temp'], edgecolors='darkblue', alpha = 0.75)

# Incorporate the other graph properties
plt.title('City Max Latitude vs. Temperature (2023-1-30)')
plt.ylabel('Max Temperature (C)')
plt.xlabel('Latitude')
plt.grid(alpha = 0.25)
# Save the figure
plt.savefig("/Users/laceymorgan/Desktop/Python_API_Challenge/output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'],city_data_df['Humidity'], edgecolors='darkblue', alpha = 0.75)

# Incorporate the other graph properties
plt.title('City Latitude vs. Humidity (2023-1-30)')
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.grid(alpha = 0.25)

# Save the figure
plt.savefig("/Users/laceymorgan/Desktop/Python_API_Challenge/output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'],city_data_df['Cloudiness'], edgecolors='darkblue', alpha = 0.75)

# Incorporate the other graph properties
plt.title('City Latitude vs. Cloudiness (2023-1-30)')
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.grid(alpha = 0.25)

# Save the figure
plt.savefig("/Users/laceymorgan/Desktop/Python_API_Challenge/output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'],city_data_df['Wind Speed'], edgecolors='darkblue', alpha = 0.75)

# Incorporate the other graph properties
plt.title('City Latitude vs. Wind Speed (2023-1-30)')
plt.ylabel('Wind Speed (m/s)')
plt.xlabel('Latitude')
plt.grid(alpha = 0.25)

# Save the figure
plt.savefig("/Users/laceymorgan/Desktop/Python_API_Challenge/output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# (slope, intercept, rvalue, pvalue, stderr) =  linregress(x, y)
# regress_values = x * slope + intercept

line_equation = f'y={slope}x + {intercept}'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/v0/rlrtvnc53g178pfy3_fzt2wm0000gp/T/ipykernel_63042/905578666.py in <module>
#       3 # regress_values = x * slope + intercept
#       4
# ----> 5 line_equation = f'y={slope}x + {intercept}'
#
# NameError: name 'slope' is not defined

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat']>= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1              mehamn  71.0357   27.8492      2.97        65          40
# 2           massakory  12.9960   15.7293     29.26        12          99
# 3             northam  51.0333   -4.2167      6.81        70          10
# 5         clyde river  70.4692  -68.5914    -30.72        90         100
# 6        beringovskiy  63.0500  179.3167    -28.03        95         100
#
#          Wind Speed Country        Date
# City_ID
# 1             19.03      NO  1675789601
# 2              4.86      TD  1675789602
# 3              1.51      GB  1675789602
# 5              0.79      CA  1675789603
# 6              3.42      RU  1675789602

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat']< 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           busselton -33.6500  115.3333     16.50        92           0
# 4        port hedland -20.3167  118.5667     28.03        83           5
# 12               tete -16.1564   33.5867     25.93        82          92
# 13           hermanus -34.4187   19.2345     21.56        74         100
# 14            ushuaia -54.8000  -68.3000     11.81        54          40
#
#          Wind Speed Country        Date
# City_ID
# 0              5.19      AU  1675789328
# 4              1.54      AU  1675789603
# 12             1.47      MZ  1675789605
# 13             6.00      ZA  1675789506
# 14             5.14      AR  1675789415

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'])
regress_values = northern_hemi_df['Lat'] * slope + intercept
n_line_equation = f'y= {round(slope,2)}x + {round(intercept,2)}'

plt.scatter(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'], edgecolors='darkblue', alpha= 0.25)

plt.plot(northern_hemi_df['Lat'], regress_values, "r-")
plt.annotate(n_line_equation, xy=(10,-20),fontsize=12,color='r')

plt.title('Northern Hemisphere Latitude vs. Max Temp (2023-1-30)')
plt.ylabel('Max Temp (C)')
plt.xlabel('Latitude')
plt.grid(alpha = 0.25)

plt.show()

print(f'the r-value is {rvalue}')
# Out:
# the r-value is -0.8564952633508658

# %%
# Linear regression on Southern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'])
regress_values = southern_hemi_df['Lat'] * slope + intercept
s_line_equation = f'y= {round(slope,2)}x + {round(intercept,2)}'

plt.scatter(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'], edgecolors='darkblue', alpha= 0.25)

plt.plot(southern_hemi_df['Lat'], regress_values, "r-")
plt.annotate(s_line_equation, xy=(-50,30),fontsize=12,color='r')

plt.title('Southern Hemisphere Latitude vs. Max Temp (2023-1-30)')
plt.ylabel('Max Temp (C)')
plt.xlabel('Latitude')
plt.grid(alpha = 0.25)

plt.show()

print(f'the r-value is {rvalue}')
# Out:
# the r-value is 0.44895318739208906

# %% [markdown]
# **Discussion about the linear relationship:** The Northern Hemisphere Latitude vs. Max Temp graph is showing a strong negative correlation between max tempuratures getting the location's proximity to the equator (latitude 0). The r-value of -.85 clearly supports observation.
#
# The data from our Southern Hemisphere cities show a moderate positive correlation between the latitude and the maximum temperature of a location. This would also support the analysis of the Northern cities, for both datasets the closer that you get to the equator the warmer it gets.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Linear regression on Northern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_hemi_df['Lat'], northern_hemi_df['Humidity'])
regress_values = northern_hemi_df['Lat'] * slope + intercept
nh_line_equation = f'y= {round(slope,2)}x + {round(intercept,2)}'

plt.scatter(northern_hemi_df['Lat'], northern_hemi_df['Humidity'], edgecolors='darkblue', alpha= 0.25)

plt.plot(northern_hemi_df['Lat'], regress_values, "r-")
plt.annotate(nh_line_equation, xy=(50,20),fontsize=12,color='r')

plt.title('Northern Hemisphere Latitude vs. Humidity (2023-1-30)')
plt.ylabel('Humidity (%')
plt.xlabel('Latitude')
plt.grid(alpha = 0.25)

plt.show()

print(f'the r-value is {rvalue}')
# Out:
# the r-value is 0.5378047272253333

# %%
# Southern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_hemi_df['Lat'], southern_hemi_df['Humidity'])
regress_values = southern_hemi_df['Lat'] * slope + intercept
sh_line_equation = f'y= {round(slope,2)}x + {round(intercept,2)}'

plt.scatter(southern_hemi_df['Lat'], southern_hemi_df['Humidity'], edgecolors='darkblue', alpha= 0.25)

plt.plot(southern_hemi_df['Lat'], regress_values, "r-")
plt.annotate(sh_line_equation, xy=(-50,80),fontsize=12,color='r')

plt.title('Southern Hemisphere Latitude vs. Humidity (2023-1-30)')
plt.ylabel('Humidity (%')
plt.xlabel('Latitude')
plt.grid(alpha = 0.25)

plt.show()

print(f'the r-value is {rvalue}')
# Out:
# the r-value is 0.2381093299449261

# %% [markdown]
# **Discussion about the linear relationship:** The Northern Hemisphere dataset shows a moderate positive correlation between latitudes getting more humid as they near the equator. The Southern Hemisphere dataset shows a weak positive correlation between these two data points.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'])
regress_values = northern_hemi_df['Lat'] * slope + intercept
nc_line_equation = f'y= {round(slope,2)}x + {round(intercept,2)}'

plt.scatter(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'], edgecolors='darkblue', alpha= 0.25)

plt.plot(northern_hemi_df['Lat'], regress_values, "r-")
plt.annotate(nc_line_equation, xy=(50,20),fontsize=12,color='r')

plt.title('Northern Hemisphere Latitude vs. Cloudiness (2023-1-30)')
plt.ylabel('Cloudiness (%')
plt.xlabel('Latitude')
plt.grid(alpha = 0.25)

plt.show()

print(f'the r-value is {rvalue}')
# Out:
# the r-value is 0.23560554281780505

# %%
# Southern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'])
regress_values = southern_hemi_df['Lat'] * slope + intercept
sc_line_equation = f'y= {round(slope,2)}x + {round(intercept,2)}'

plt.scatter(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'], edgecolors='darkblue', alpha= 0.25)

plt.plot(southern_hemi_df['Lat'], regress_values, "r-")
plt.annotate(sc_line_equation, xy=(-50,60),fontsize=12,color='r')

plt.title('Southern Hemisphere Latitude vs. Cloudiness (2023-1-30)')
plt.ylabel('Cloudiness (%')
plt.xlabel('Latitude')
plt.grid(alpha = 0.25)

plt.show()

print(f'the r-value is {rvalue}')
# Out:
# the r-value is 0.3262240543142496

# %% [markdown]
# **Discussion about the linear relationship:** Both the Northern and Southern Hemisphere datasets show weak correlation between latitude and cloudiness.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'])
regress_values = northern_hemi_df['Lat'] * slope + intercept
nw_line_equation = f'y= {round(slope,2)}x + {round(intercept,2)}'

plt.scatter(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'], edgecolors='darkblue', alpha= 0.25)

plt.plot(northern_hemi_df['Lat'], regress_values, "r-")
plt.annotate(nw_line_equation, xy=(10,14),fontsize=12,color='r')

plt.title('Northern Hemisphere Latitude vs. Wind Speed (2023-1-30)')
plt.ylabel('Wind Speed (m/s)')
plt.xlabel('Latitude')
plt.grid(alpha = 0.25)

plt.show()

print(f'the r-value is {rvalue}')
# Out:
# the r-value is 0.09318728254790885

# %%
# Southern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'])
regress_values = southern_hemi_df['Lat'] * slope + intercept
sw_line_equation = f'y= {round(slope,2)}x + {round(intercept,2)}'

plt.scatter(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'], edgecolors='darkblue', alpha= 0.25)

plt.plot(southern_hemi_df['Lat'], regress_values, "r-")
plt.annotate(sw_line_equation, xy=(-50,12),fontsize=12,color='r')

plt.title('Southern Hemisphere Latitude vs. Wind Speed (2023-1-30)')
plt.ylabel('Wind Speed (m/s)')
plt.xlabel('Latitude')
plt.grid(alpha = 0.25)

plt.show()

print(f'the r-value is {rvalue}')
# Out:
# the r-value is -0.17949488498245086

# %% [markdown]
# **Discussion about the linear relationship:** The Northern Hemisphere dataset is showing a very weak correlation between latitude and windspeed, there is no connection here. The Southern dataset shows as a weak negative correlation, so based on what I am seeing here I can't say that there is a correlation between city location and wind speed.
